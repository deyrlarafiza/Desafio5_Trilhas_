# %% [markdown]
# <a href="https://colab.research.google.com/github/deyrlarafiza/Desafio5_Trilhas_/blob/main/Desafio5_Trilhas_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 5º Desafio - Ciência de Dados
#
# ## Deyrla Rafiza
#
# - ***Lançamento:* 08/07**
# - ***Entrega:* até o dia 28/07**
# - **Desafio individual**
#
# **🫡Sua missão :**
#
# <aside>
# 🛠 Utilizando suas habilidades ninja em Python e bibliotecas como Pandas e Seaborn, você deve aplicá-las para:
#
# </aside>
#
# 1. Substituir o cabeçalho por palavras em letras maiúsculas;
# 2. Corrigir os dados faltantes e preencher as lacunas com valores adequados;
# 3. Eliminar os outliers, atribuindo no lugar deles os valores adequados;
# 4. Eliminar os duplicados, para garantir a unicidade das informações;
# 5. Substituir os NANs por valores adequados;
# 6. Corrigir os dados categóricos, por exemplo, "Mas" para "Masculino" e "Fem" para "Feminino" para adequá-los ao padrão dos demais;
# 7. Vá além das dicas fornecidas, para melhorar a sua habilidade em limpeza e tratamento de dados.

# %% [markdown]
# #IMPORTACAO DE BIBLIOTECAS

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/Planilha do desafio 5 - Ciência de dados - Relatório do Banco x.csv')
df.head()
# Out:
#    Id  Pontos Estado    Genero  Idade  Bens  Saldo na Conta  Produto  \
# 0   1     619     BA  Feminino     42     2               0        1
# 1   2     608     CE  Feminino     41     1         8380786        1
# 2   3     502     BA  Feminino     42     8         1596608        3
# 3   4     699     BA  Feminino     39     1               0        2
# 4   5     850     CE  Feminino     43     2        12551082        1
#
#    Possui cartao  Ativo     Salario  Saiu
# 0              1      1  10134888.0     1
# 1              0      1  11254258.0     0
# 2              1      0  11393157.0     1
# 3              0      0   9382663.0     0
# 4              1      1    790841.0     0

# %% [markdown]
#  # Substitui os nomes das colunas por letras maiúsculas

# %%
df.columns = df.columns.str.upper()
df.head()
# Out:
#    ID  PONTOS ESTADO    GENERO  IDADE  BENS  SALDO NA CONTA  PRODUTO  \
# 0   1     619     BA  Feminino     42     2               0        1
# 1   2     608     CE  Feminino     41     1         8380786        1
# 2   3     502     BA  Feminino     42     8         1596608        3
# 3   4     699     BA  Feminino     39     1               0        2
# 4   5     850     CE  Feminino     43     2        12551082        1
#
#    POSSUI CARTAO  ATIVO     SALARIO  SAIU
# 0              1      1  10134888.0     1
# 1              0      1  11254258.0     0
# 2              1      0  11393157.0     1
# 3              0      0   9382663.0     0
# 4              1      1    790841.0     0

# %% [markdown]
# #GENERO

# %%
df['GENERO'].value_counts()
# Out:
# GENERO
# Masculino    521
# Feminino     461
# M              6
# F              2
# Fem            1
# Name: count, dtype: int64

# %%
# @title Estado vs Genero

from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['GENERO'].value_counts()
    for x_label, grp in df.groupby('ESTADO')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Estado')
_ = plt.ylabel('Genero')

# %%
df.groupby('GENERO').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# # Corrigir os dados categóricos, por exemplo, "Mas" para "Masculino" e "Fem" para "Feminino" para adequá-los ao padrão dos demais

# %%
df['GENERO'] = df['GENERO'].replace({'M': 'Masculino', 'F': 'Feminino','Fem':'Feminino'})
df['GENERO'].value_counts()
# Out:
# GENERO
# Masculino    527
# Feminino     464
# Name: count, dtype: int64

# %%
df.groupby('GENERO').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Estado vs Genero

from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['GENERO'].value_counts()
    for x_label, grp in df.groupby('ESTADO')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Estado')
_ = plt.ylabel('Genero')

# %% [markdown]
# # Verificação de valores nulos

# %%
df.isnull().sum()
# Out:
# ID                0
# PONTOS            0
# ESTADO            0
# GENERO            8
# IDADE             0
# BENS              0
# SALDO NA CONTA    0
# PRODUTO           0
# POSSUI CARTAO     0
# ATIVO             0
# SALARIO           7
# SAIU              0
# dtype: int64

# %%
nulos_genero = df[df['GENERO'].isna()]
nulos_genero
# Out:
#       ID  PONTOS ESTADO GENERO  IDADE  BENS  SALDO NA CONTA  PRODUTO  \
# 64    65     603     MG    NaN     26     4        10916637        1
# 84    86     493     MA    NaN     46     4               0        2
# 213  215     676     MA    NaN     34     1         6309501        1
# 296  298     714     MA    NaN     31     4        12516926        1
# 370  372     801     CE    NaN     42     4        14194767        1
# 501  503     692     MA    NaN     54     5               0        2
# 963  965     529     CE    NaN     63     4         9613411        3
# 969  971     649     CE    NaN     70     9        11685471        2
#
#      POSSUI CARTAO  ATIVO     SALARIO  SAIU
# 64               1      1   9284067.0     0
# 84               1      0    190766.0     0
# 213              1      1   4064581.0     0
# 296              1      1  10663689.0     0
# 370              1      1   1059829.0     0
# 501              1      1   8872184.0     0
# 963              1      0  10873296.0     1
# 969              0      1  10712579.0     0

# %% [markdown]
# # Calcular a moda da coluna 'GENERO'

# %%
moda_genero = df['GENERO'].mode()[0]
moda_genero
# Out:
# 'Masculino'

# %%
# Substituir os valores nulos pela moda
df['GENERO'].fillna(moda_genero, inplace=True)

# %%
# valores NaN
df.isna().sum()
# Out:
# ID                0
# PONTOS            0
# ESTADO            0
# GENERO            0
# IDADE             0
# BENS              0
# SALDO NA CONTA    0
# PRODUTO           0
# POSSUI CARTAO     0
# ATIVO             0
# SALARIO           7
# SAIU              0
# dtype: int64

# %% [markdown]
# # Imputando valores faltantes com a média da coluna para colunas numéricas

# %%
for column in df.select_dtypes(include=['number']):
    df[column] = df[column].fillna(df[column].mean())

# %% [markdown]
# # Imputando valores faltantes com a moda da coluna para colunas categóricas

# %%
for column in df.select_dtypes(include=['category']):
    df[column] = df[column].fillna(df[column].mode()[0])

# %% [markdown]
# # Verificando se ainda existem valores faltantes

# %%
print(df.isnull().sum())
# Out:
# ID                0
# PONTOS            0
# ESTADO            0
# GENERO            0
# IDADE             0
# BENS              0
# SALDO NA CONTA    0
# PRODUTO           0
# POSSUI CARTAO     0
# ATIVO             0
# SALARIO           0
# SAIU              0
# dtype: int64

# %%
df
# Out:
#        ID  PONTOS ESTADO     GENERO  IDADE  BENS  SALDO NA CONTA  PRODUTO  \
# 0       1     619     BA   Feminino     42     2               0        1
# 1       2     608     CE   Feminino     41     1         8380786        1
# 2       3     502     BA   Feminino     42     8         1596608        3
# 3       4     699     BA   Feminino     39     1               0        2
# 4       5     850     CE   Feminino     43     2        12551082        1
# ..    ...     ...    ...        ...    ...   ...             ...      ...
# 994   996     838     CE  Masculino     43     9        12310588        2
# 995   997     610     CE  Masculino     29     9               0        3
# 996   998     811     CE  Masculino     44     3               0        2
# 997   999     587     CE  Masculino     62     7        12128627        1
# 998  1000     811     CE   Feminino     28     4        16773882        2
#
#      POSSUI CARTAO  ATIVO     SALARIO  SAIU
# 0                1      1  10134888.0     1
# 1                0      1  11254258.0     0
# 2                1      0  11393157.0     1
# 3                0      0   9382663.0     0
# 4                1      1    790841.0     0
# ..             ...    ...         ...   ...
# 994              1      0  14576583.0     0
# 995              0      1   8391224.0     0
# 996              0      1   7843973.0     0
# 997              0      1    677692.0     0
# 998              1      1    990342.0     0
#
# [999 rows x 12 columns]

# %% [markdown]
# ##Verificação de Outiliers

# %%
# @title PONTOS vs IDADE
df.plot(kind='scatter', x='PONTOS', y='IDADE', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
def identify_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    return outliers

# %% [markdown]
# ## Verificar outliers na coluna 'IDADE'

# %%
outliers_idade = identify_outliers_iqr(df, 'IDADE')
print("Outliers na coluna 'IDADE':")
print(outliers_idade)
# Out:
# Outliers na coluna 'IDADE':
#       ID  PONTOS ESTADO     GENERO  IDADE  BENS  SALDO NA CONTA  PRODUTO  \
# 58    59     511     CE   Feminino     66     4               0        1
# 85    87     652     CE   Feminino     75    10               0        2
# 104  106     670     CE   Feminino     65     1               0        1
# 158  160     646     MA   Feminino     73     6         9725925        1
# 181  183     510     MA  Masculino     65     2               0        2
# 230  232     673     MA  Masculino     72     1               0        2
# 234  236     585     MA   Feminino     67     5        11397897        2
# 243  245     659     CE  Masculino     67     6         1174116        1
# 252  254     681     MA   Feminino     79     0               0        2
# 310  312     652     MA   Feminino     80     4               0        2
# 364  366     640     MA  Masculino     68     9               0        2
# 371  373     640     CE   Feminino     75     1        10630791        2
# 385  387     560     MA   Feminino     66     9               0        1
# 399  401     616     MA   Feminino     66     1        13584241        1
# 559  561     850     CE   Feminino     70     5               0        1
# 567  569     687     CE   Feminino     63     1        13771566        1
# 602  604     687     MA   Feminino     72     9               0        1
# 612  614     605     MA   Feminino     64     2         1295557        1
# 658  660     544     MA  Masculino     64     9        11382945        1
# 678  680     788     CE   Feminino     70     1               0        2
# 736  738     816     CE  Masculino     67     6        15185898        1
# 766  768     700     MA   Feminino     82     2               0        2
# 769  771     531     MA   Feminino     63     1        11471571        1
# 807  809     628     MA  Masculino     69     5               0        2
# 811  813     681     CE  Masculino     65     7         1347147        2
# 823  825     732     CE   Feminino     69     9        13745343        1
# 851  853     667     CE   Feminino      0     1         9713392        2
# 859  861     598     MA  Masculino     64     1               0        2
# 867  869     636     MA   Feminino    -10     1        17083346        1
# 884  886     515     MA  Masculino     65     7         9211361        1
# 887  889     585     MA  Masculino      0     2               0        2
# 888  890     733     CE  Masculino     74     3        10654553        1
# 930  932     661     CE  Masculino      0     6        13262898        1
# 931  933     564     CE  Masculino      0     9        10352275        2
# 947  949     715     MA   Feminino      0     5        11859041        1
# 948  950     659     MA  Masculino     67     4        14598187        1
# 952  954     571     CE   Feminino     66     9        11157701        1
# 957  959     771     CE   Feminino     67     8               0        2
# 963  965     529     CE  Masculino     63     4         9613411        3
# 969  971     649     CE  Masculino     70     9        11685471        2
# 984  986     773     MA  Masculino    -20     1        12453278        2
# 990  992     655     MA  Masculino    140     5           93147        2
#
#      POSSUI CARTAO  ATIVO       SALARIO  SAIU
# 58               1      0  1.643110e+05     1
# 85               1      1  1.146758e+07     0
# 104              1      1  1.776557e+07     1
# 158              0      1  1.047197e+07     0
# 181              1      1  4.807161e+06     0
# 230              0      1  1.119812e+09     0
# 234              0      1  9.314611e+06     0
# 243              1      1  4.507109e+06     1
# 252              0      1  1.709690e+07     0
# 310              1      1  1.886031e+07     0
# 364              1      1  1.994934e+07     0
# 371              0      1  1.134288e+07     0
# 385              1      1  1.592849e+06     0
# 399              1      0  1.838405e+07     1
# 559              1      1  7.051800e+04     0
# 567              1      1  3.793874e+06     0
# 602              0      1  6.982940e+05     0
# 612              1      1  1.360179e+06     0
# 658              1      1  1.243415e+07     0
# 678              1      1  4.161062e+06     0
# 736              1      1  7.281431e+06     0
# 766              0      1  1.820554e+07     0
# 769              0      1  2.450695e+06     1
# 807              1      1  1.819646e+06     0
# 811              0      1  1.904198e+07     0
# 823              0      1  1.109322e+07     1
# 851              0      0  1.133168e+07     1
# 859              1      0  1.956353e+06     1
# 867              1      0  1.105103e+07     1
# 884              1      1  1.425483e+07     0
# 887              1      1  1.865777e+06     0
# 888              1      1  1.345896e+07     0
# 930              0      0  3.881267e+06     0
# 931              1      1  3.433821e+06     0
# 947              1      1  5.684170e+05     1
# 948              1      1  1.310432e+06     0
# 952              0      1  1.892719e+06     0
# 957              1      1  5.121980e+05     0
# 963              1      0  1.087330e+07     1
# 969              0      1  1.071258e+07     0
# 984              0      1  1.172357e+06     0
# 990              1      0  6.621413e+06     0

# %% [markdown]
# ## Manter a Última Ocorrência

# %%
df.drop_duplicates(keep='last', inplace=True)

# %% [markdown]
# ## Eliminar Duplicados Baseados em Colunas Específicas

# %%
df.drop_duplicates(subset=['ID', 'GENERO'], inplace=True)

# %% [markdown]
# ##Resetar o Índice Após Remover Duplicados

# %%
df.drop_duplicates(inplace=True)
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## Verificar duplicados

# %%
duplicados = df.duplicated()
duplicados
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 993    False
# 994    False
# 995    False
# 996    False
# 997    False
# Length: 998, dtype: bool

# %%
print(df[duplicados])
# Out:
# Empty DataFrame
# Columns: [ID, PONTOS, ESTADO, GENERO, IDADE, BENS, SALDO NA CONTA, PRODUTO, POSSUI CARTAO, ATIVO, SALARIO, SAIU]
# Index: []

# %% [markdown]
# ## Identificar idades negativas

# %%
idades_negativas = df[df['IDADE'] <= 0]
idades_negativas
# Out:
#       ID  PONTOS ESTADO     GENERO  IDADE  BENS  SALDO NA CONTA  PRODUTO  \
# 850  853     667     CE   Feminino    0.0     1         9713392        2
# 886  889     585     MA  Masculino    0.0     2               0        2
# 929  932     661     CE  Masculino    0.0     6        13262898        1
# 930  933     564     CE  Masculino    0.0     9        10352275        2
# 946  949     715     MA   Feminino    0.0     5        11859041        1
#
#      POSSUI CARTAO  ATIVO     SALARIO  SAIU
# 850              0      0  11331677.0     1
# 886              1      1   1865777.0     0
# 929              0      0   3881267.0     0
# 930              1      1   3433821.0     0
# 946              1      1    568417.0     1

# %% [markdown]
# ## Exibir idades negativas

# %%
print("\nLinhas com idades negativas:")
print(idades_negativas)
# Out:
# Linhas com idades negativas:
#       ID  PONTOS ESTADO     GENERO  IDADE  BENS  SALDO NA CONTA  PRODUTO  \
# 850  853     667     CE   Feminino    0.0     1         9713392        2
# 886  889     585     MA  Masculino    0.0     2               0        2
# 929  932     661     CE  Masculino    0.0     6        13262898        1
# 930  933     564     CE  Masculino    0.0     9        10352275        2
# 946  949     715     MA   Feminino    0.0     5        11859041        1
#
#      POSSUI CARTAO  ATIVO     SALARIO  SAIU
# 850              0      0  11331677.0     1
# 886              1      1   1865777.0     0
# 929              0      0   3881267.0     0
# 930              1      1   3433821.0     0
# 946              1      1    568417.0     1

# %% [markdown]
# ## Calcular a média das idades não negativas

# %%
media_idades = df[df['IDADE'] >= 0]['IDADE'].mean()

# %% [markdown]
# # Substituir idades negativas pela média das idades não negativas

# %%
df.loc[df['IDADE'] < 0, 'IDADE'] = media_idades

# %% [markdown]
# ## Exibir o DataFrame após a correção

# %%
print("\nDataFrame após substituir as idades negativas pela média das idades não negativas:")
print(df)
# Out:
# DataFrame após substituir as idades negativas pela média das idades não negativas:
#        ID  PONTOS ESTADO     GENERO  IDADE  BENS  SALDO NA CONTA  PRODUTO  \
# 0       1     619     BA   Feminino   42.0     2               0        1
# 1       2     608     CE   Feminino   41.0     1         8380786        1
# 2       3     502     BA   Feminino   42.0     8         1596608        3
# 3       4     699     BA   Feminino   39.0     1               0        2
# 4       5     850     CE   Feminino   43.0     2        12551082        1
# ..    ...     ...    ...        ...    ...   ...             ...      ...
# 993   996     838     CE  Masculino   43.0     9        12310588        2
# 994   997     610     CE  Masculino   29.0     9               0        3
# 995   998     811     CE  Masculino   44.0     3               0        2
# 996   999     587     CE  Masculino   62.0     7        12128627        1
# 997  1000     811     CE   Feminino   28.0     4        16773882        2
#
#      POSSUI CARTAO  ATIVO     SALARIO  SAIU
# 0                1      1  10134888.0     1
# 1                0      1  11254258.0     0
# 2                1      0  11393157.0     1
# 3                0      0   9382663.0     0
# 4                1      1    790841.0     0
# ..             ...    ...         ...   ...
# 993              1      0  14576583.0     0
# 994              0      1   8391224.0     0
# 995              0      1   7843973.0     0
# 996              0      1    677692.0     0
# 997              1      1    990342.0     0
#
# [998 rows x 12 columns]

# %%
df.head()
# Out:
#    ID  PONTOS ESTADO    GENERO  IDADE  BENS  SALDO NA CONTA  PRODUTO  \
# 0   1     619     BA  Feminino   42.0     2               0        1
# 1   2     608     CE  Feminino   41.0     1         8380786        1
# 2   3     502     BA  Feminino   42.0     8         1596608        3
# 3   4     699     BA  Feminino   39.0     1               0        2
# 4   5     850     CE  Feminino   43.0     2        12551082        1
#
#    POSSUI CARTAO  ATIVO     SALARIO  SAIU
# 0              1      1  10134888.0     1
# 1              0      1  11254258.0     0
# 2              1      0  11393157.0     1
# 3              0      0   9382663.0     0
# 4              1      1    790841.0     0

# %%
# @title Estado

from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('ESTADO').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Pontos vs Idade

from matplotlib import pyplot as plt
df.plot(kind='scatter', x='PONTOS', y='IDADE', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)
